# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r'c:/Users/ilike/1.data/lab-customer-analysis-round-2/files_for_lab/csv_files/marketing_customer_analysis.csv')

# %% [markdown]
# Dealing with the data
# Show the dataframe shape.

# %%
data.shape
# Out:
# (10910, 26)

# %%
data1=data.copy()

# %%
data1.columns=data1.columns.str.lower().str.replace(" ","_")

# %%
data1
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# Which columns are numerical?
# Which columns are categorical?

# %%
numerical=data1.select_dtypes("number")

# %%
numerical
# Out:
#        unnamed:_0  customer_lifetime_value  income  monthly_premium_auto  \
# 0               0              4809.216960   48029                    61
# 1               1              2228.525238       0                    64
# 2               2             14947.917300   22139                   100
# 3               3             22332.439460   49078                    97
# 4               4              9025.067525   23675                   117
# ...           ...                      ...     ...                   ...
# 10905       10905             15563.369440       0                   253
# 10906       10906              5259.444853   61146                    65
# 10907       10907             23893.304100   39837                   201
# 10908       10908             11971.977650   64195                   158
# 10909       10909              6857.519928       0                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# ...

# %%
numerical.isna().sum()
# Out:
# unnamed:_0                         0
# customer_lifetime_value            0
# income                             0
# monthly_premium_auto               0
# months_since_last_claim          633
# months_since_policy_inception      0
# number_of_open_complaints        633
# number_of_policies                 0
# total_claim_amount                 0
# dtype: int64

# %%
categorical=data1.select_dtypes("object")

# %%
categorical
# Out:
#       customer       state response  coverage education effective_to_date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location_code marital_status     policy_type  \
# ...

# %%
categorical.columns
# Out:
# Index(['customer', 'state', 'response', 'coverage', 'education',
#        'effective_to_date', 'employmentstatus', 'gender', 'location_code',
#        'marital_status', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'vehicle_class', 'vehicle_size', 'vehicle_type'],
#       dtype='object')

# %% [markdown]
# Check and deal with NaN values.

# %%
data1.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim           633
# months_since_policy_inception       0
# number_of_open_complaints         633
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
data1.fillna(data1.median(numeric_only=True), inplace=True)

# %%
data1.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim             0
# months_since_policy_inception       0
# number_of_open_complaints           0
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
#data1[categorical.columns].fillna("", inplace=True) - not working

# %%
data1.isna().sum()
# Out:
# unnamed:_0                          0
# customer                            0
# state                             631
# customer_lifetime_value             0
# response                          631
# coverage                            0
# education                           0
# effective_to_date                   0
# employmentstatus                    0
# gender                              0
# income                              0
# location_code                       0
# marital_status                      0
# monthly_premium_auto                0
# months_since_last_claim             0
# months_since_policy_inception       0
# number_of_open_complaints           0
# number_of_policies                  0
# policy_type                         0
# policy                              0
# renew_offer_type                    0
# sales_channel                       0
# total_claim_amount                  0
# vehicle_class                     622
# vehicle_size                      622
# ...

# %%
data1.loc[:, categorical.columns] = data1.loc[:, categorical.columns].fillna(" ")

# %%
#When using .loc, the general syntax is dataframe.loc[row_indexer, column_indexer]. By using : before categorical.columns, we are specifying that we want to select all rows in the DataFrame.

# %%
data1.isna().sum()
# Out:
# unnamed:_0                       0
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# vehicle_type                     0
# dtype: int64

# %% [markdown]
# Datetime format - Extract the months from the dataset and store in a separate column.

# %%
data1
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877                          6857.519928
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
Date = data1[["effective_to_date"]]

# %%
print(type(Date))
Date
# Out:
# <class 'pandas.core.frame.DataFrame'>
#       effective_to_date
# 0               2/18/11
# 1               1/18/11
# 2               2/10/11
# 3               1/11/11
# 4               1/17/11
# ...                 ...
# 10905           1/19/11
# 10906            1/6/11
# 10907            2/6/11
# 10908           2/13/11
# 10909            1/8/11
#
# [10910 rows x 1 columns]

# %%
pd.to_datetime(Date, format='%Y-%M-%D')
Date
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_37824\2703500733.py in <module>
# ----> 1 pd.to_datetime(Date, format='%Y-%M-%D')
#       2 Date
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1052             result = arg._constructor(values, index=arg.index, name=arg.name)
#    1053     elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
# -> 1054         result = _assemble_from_unit_mappings(arg, errors, tz)
#    1055     elif isinstance(arg, Index):
#    1056         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _assemble_from_unit_mappings(arg, errors, tz)
#    1158     if len(req):
# ...

# %%
data1['effective_to_date'] = pd.to_datetime(data1['effective_to_date'], format='%m/%d/%y')
data1
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877                          6857.519928
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# Then filter the data to show only the information for the first quarter , ie. January, February and March. Hint: If data from March does not exist, consider only January and February.
# BONUS: Put all the previously mentioned data transformations into a function.

# %%
#firstQ=data[data1['effective_to_date'].dt.quarter == 1].sort_values('effective_to_date')

firstQ=data1[data1['effective_to_date'].dt.quarter ==1].sort_values('effective_to_date')
firstQ
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 10823       10823  AH53588  California              4636.546470      Yes
# 3851         3851  OG30514      Nevada             20018.204590       No
# 3855         3855  NU64028      Nevada             12265.600410       No
# 3863         3863  HJ21793      Oregon              4648.539191       No
# 10407       10407  NK53938      Oregon              2599.968438       No
# ...           ...      ...         ...                      ...      ...
# 836           836  OV54878  California              4639.035171       No
# 840           840  OS95734  California              7074.398104       No
# 4421         4421  VE98553      Oregon              4666.643522       No
# 8664         8664  FL50532     Arizona              8237.251407       No
# 4696         4696  GU82757  California              4376.363592      Yes
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...
